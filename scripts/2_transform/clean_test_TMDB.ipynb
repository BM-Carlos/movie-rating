# %%
import pandas as pd
from pathlib import Path

# %%
BASE_DIR = Path.cwd().parent.parent
RAW_DIR = BASE_DIR / "data" / "1_raw"

movies_absolute_path = f"{RAW_DIR}\\TMDB\\TMDB_top_rated_movies.csv"
shows_absolute_path = f"{RAW_DIR}\\TMDB\\TMDB_top_rated_shows.csv"

movies = pd.read_csv(movies_absolute_path, sep=';', index_col=0)
shows = pd.read_csv(shows_absolute_path, sep=';', index_col=0)

# %%
display(shows)
# Out:
#       adult                     backdrop_path                      genre_ids  \
# 0     False  /9faGSFi5jam6pDWGNd0p8JcJgXQ.jpg                       [18, 80]
# 1     False  /5yk3QwnQxzwKfhU1tlDkV2PSIBz.jpg                           [18]
# 2     False  /96RT2A47UdzWlUfvIERFyBsLhL2.jpg         [16, 10759, 10765, 18]
# 3     False  /wQEW3xLrQAThu1GvqpsKQyejrYS.jpg         [16, 10765, 18, 10759]
# 4     False  /7BzmK4MWc0cj4hCxwWURt6TS6UR.jpg         [16, 10765, 10759, 35]
# ...     ...                               ...                            ...
# 2175  False  /o2F0cIIuEOuai7Vzv0Rh7YvRppT.jpg                [10759, 18, 80]
# 2176  False  /x8pSFa3BXyVpkjHyn7YxmLyhjoh.jpg                        [10764]
# 2177  False  /5W9YCPMDF5TCudct2guf6b8iRFz.jpg             [18, 10765, 10759]
# 2178  False  /k3jqkKB6gDXNDLYyfTLskCwxw6M.jpg  [10762, 16, 35, 10759, 10765]
# 2179  False  /2CmVYL5aOebxlE4cUl5xU4kcgdc.jpg                       [16, 35]
#
#           id origin_country original_language                  original_name  \
# 0       1396         ['US']                en                   Breaking Bad
# 1     219246         ['KR']                ko                        폭싹 속았수다
# 2     209867         ['JP']                ja                       葬送のフリーレン
# 3      94605         ['US']                en                         Arcane
# 4     131378         ['US']                en  Adventure Time: Fionna & Cake
# ...      ...            ...               ...                            ...
# 2175    4386         ['US']                en                       Baywatch
# 2176   37678         ['US']                en                      The Voice
# 2177   68716         ['US']                en              Marvel's Inhumans
# 2178   68295   ['GB', 'US']                en                         Ben 10
# 2179   15632         ['US']                en             The Cleveland Show
#
#                                                overview  popularity  \
# 0     Tras cumplir 50 años, Walter White (Bryan Cran...    113.0631
# 1     En la isla de Jeju, una chica llena de vida y ...     68.3638
# 2     La maga Frieren formaba parte del grupo del hé...     25.4789
# 3     Con las dispares ciudades de Piltover y Zaun c...     29.4816
# 4     Fionna y Cake, con la ayuda del anterior Rey d...     11.2676
# ...                                                 ...         ...
# 2175  Serie de TV (1989-2001). 11 temporadas. 242 ep...     61.2533
# 2176  Los cantantes aficionados compiten por los máx...     44.9912
# 2177  Se centra en la historia de la familia real de...      6.4415
# 2178  Con la quinta parte de la franquicia "Ben 10",...     51.5241
# 2179  The Cleveland Show, es una serie estado estado...     16.6085
#
#                            poster_path first_air_date  \
# 0     /ztkUQFLlC19CCMYHW9o1zWhJRNq.jpg     2008-01-20
# 1     /h3Sv1qMAc6ADS6xWoIrUAzdXarf.jpg     2025-03-07
# 2     /v7i3yNKxsDwB5IG9ElWgOGPieE8.jpg     2023-09-29
# 3     /i1vSPUbiBe2iK2HapGDfHItBFlC.jpg     2021-11-06
# 4     /2tgXQ9NU48mNgpsEWfyVzTb2Ho8.jpg     2023-08-31
# ...                                ...            ...
# 2175  /nv7O01pEiHYNQNvQDgkAp3qEwb7.jpg     1989-04-23
# 2176  /8jgjykcCuQ5rYreyqba4mazNKYd.jpg     2011-04-26
# 2177  /zKfGip55oJ9tdzhyd9ayGyFFhuo.jpg     2017-09-29
# 2178  /a4H0UR7aUkGZlT6Q9r9grBrjJWR.jpg     2016-10-01
# 2179   /Qp4gvTc5Cp15VBdt77oXKQ54xF.jpg     2009-09-27
#
#                                   name  vote_average  vote_count  type
# 0                         Breaking Bad         8.925       15515  show
# 1       Si la vida te da mandarinas...         8.900         256  show
# 2     Frieren: Tras finalizar el viaje         8.778         431  show
# 3                               Arcane         8.776        5113  show
# 4     Hora de aventuras: Fionna y Cake         8.758         231  show
# ...                                ...           ...         ...   ...
# 2175        Los vigilantes de la playa         5.943         491  show
# 2176                         The Voice         5.925         206  show
# 2177                          Inhumans         5.914         702  show
# 2178                            Ben 10         5.903         201  show
# 2179              El show de Cleveland         5.885         426  show
#
# [2180 rows x 15 columns]
